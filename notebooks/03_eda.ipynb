# %% [markdown]
# # 03 - Exploratory Data Analysis

# %%
from pathlib import Path
import sys, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

BASE_DIR = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
SRC_DIR = BASE_DIR / "src"
sys.path.insert(0, str(SRC_DIR))

DATA_RAW = BASE_DIR / "data" / "raw"
DATA_PROCESSED = BASE_DIR / "data" / "processed"
REPORTS = BASE_DIR / "reports"
FIGURES = REPORTS / "figures"
MODELS = BASE_DIR / "models"

print("Project:", BASE_DIR)
print("Artifacts present:", REPORTS.exists(), FIGURES.exists(), MODELS.exists())
# Out:
# Project: C:\Users\Province Settat\Desktop\ML\project
# Artifacts present: True True True

# %% [markdown]
# Review the generated exploratory figures and confirm that they exist.

# %%
eda_figures = [
    "class_distribution.png",
    "missing_values.png",
    "descriptor_distributions.png",
    "descriptor_boxplots.png",
    "correlation_matrix.png",
]
for name in eda_figures:
    path = FIGURES / name
    print(f"{name:35s}", path.exists(), path)
# Out:
# class_distribution.png              True C:\Users\Province Settat\Desktop\ML\project\reports\figures\class_distribution.png
# missing_values.png                  True C:\Users\Province Settat\Desktop\ML\project\reports\figures\missing_values.png
# descriptor_distributions.png        True C:\Users\Province Settat\Desktop\ML\project\reports\figures\descriptor_distributions.png
# descriptor_boxplots.png             True C:\Users\Province Settat\Desktop\ML\project\reports\figures\descriptor_boxplots.png
# correlation_matrix.png              True C:\Users\Province Settat\Desktop\ML\project\reports\figures\correlation_matrix.png

# %%
from IPython.display import Image, display
display(Image(filename=str(FIGURES / "class_distribution.png")))
display(Image(filename=str(FIGURES / "missing_values.png")))
